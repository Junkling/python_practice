# %% [markdown]
# ---
# # 파이썬 입문 : 도전! 45가지 기초 문법 실습하기 🙋🏻‍♂️
# ---

# %% [markdown]
# ### 꼭 기억하세요 😊
# + **시간이 다소 소요되더라도** 스스로 생각해서 프로그래밍을 해야**`실력이 향상 됩니다.`**
# + 다양한 문제를 통해서 **`문제 해결`**능력을 향상 시켜봐요.
# + 여러 방식으로 **`같은 결과 값`**이 나오도록 프로그래밍 해보세요.
# + **문제 해결**에 너무 시간이 오래 걸리면 **`검색(구글링 등)`**을 통해서 해결해보세요.
# + **`온라인 Python IDE :`** https://www.programiz.com/python-programming/online-compiler/

# %% [markdown]
# ***
# ## 2. Assigning & Comparison💻
# ***
# #### **`연습예제1`** 💻

# %% [markdown]
# `아래 파이썬 코드의 결과 값을` **`True or False`**  `값을 예상하고 아래 코딩영역에 작성하세요.`
#
# ```python
# x = 15
# y = 25
#
# print(f'x == y : {x == y}')
# print(f'x is y : {x is y}')
#
# # print(f'x value, id : {x}, {hex(id(x))}')
# # print(f'y value, id : {y}, {hex(id(y))}')
# ```

# %% [markdown]
# #### **`코딩영역1`**

# %%
# 코딩 영역
import this

x = 15
y = 25
# False
print(f'x == y : {x == y}')
# False
print(f'x is y : {x is y}')
# Out:
# x == y : False
# x is y : False

# %% [markdown]
# ***
# #### **`연습예제2`**

# %% [markdown]
# `아래 파이썬 코드의 결과 값을` **`True or False`**  `값을 예상하고 아래 코딩영역에 작성하세요.`
#
# ```python
# x = ['orange', 'banana', 'apple']
# y = x
#
# print(f'x == y : {x == y}')
# print(f'x is y : {x is y}')
#
# # print(f'x value, id : {x}, {hex(id(x))}')
# # print(f'y value, id : {y}, {hex(id(y))}')
# ```

# %% [markdown]
# #### **`코딩영역2`**

# %%
# 코딩 영역
import this

x = ['orange', 'banana', 'apple']
y = x

#Ture
print(f'x == y : {x == y}')
#Ture
print(f'x is y : {x is y}')
# Out:
# x == y : True
# x is y : True

# %% [markdown]
# ***
# #### **`연습예제3`**

# %% [markdown]
# `아래 파이썬 코드의 결과 값을` **`True or False`**  `값을 예상하고 아래 코딩영역에 작성하세요.`
#
# ```python
# x = ['orange', 'banana', 'apple']
# y = ['orange', 'banana', 'apple']
#
# print(f'x == y : {x == y}')
# print(f'x is y : {x is y}')
#
# # print(f'x value, id : {x}, {hex(id(x))}')
# # print(f'y value, id : {y}, {hex(id(y))}')
# ```

# %% [markdown]
# #### **`코딩영역3`**

# %%
# 코딩 영역
import this

x = ['orange', 'banana', 'apple']
y = ['orange', 'banana', 'apple']

# False 일듯 (같은 객체 주소가 아닐것 같음)
print(f'x == y : {x == y}')

# True 일듯 -> equals 와 비슷할듯
print(f'x is y : {x is y}')

print(id(x))
print(hex(id(x)))
print(id(y))
print(hex(id(y)))
# 반대였음
# 정답 -> is 는 객체 주소값이 같은지(실제로 같은지) == 는 내부 값이 동일한지 비교
# Out:
# x == y : True
# x is y : False
# 4570375872
# 0x1106a66c0
# 4570372608
# 0x1106a5a00

# %%
#추가 설명
a = 15
b = 25
print(a == b)
print(a is b)

c = []
d = c
e = c + d
# 빈배열로 값이 같을 듯

print('''
c = []
d = c
e = c + d
''')
print('c : ',c)
print('d : ',d)
print('e : ',e)

print('c == d : ', c == d)

# 값이 같기 때문에 같을듯
print('e == d : ',e == d)

# 빈배열로 값이 같을 듯
print('c is d : ',c is d)

# 두 배열을 합한 다른 메모리 영역으로 다를 듯
print('e is d : ',e is d)
# Out:
# False
# False
#
# c = []
# d = c
# e = c + d
#
# c :  []
# d :  []
# e :  []
# c == d :  True
# e == d :  True
# c is d :  True
# e is d :  False

# %% [markdown]
# #### **`Hint`**

# %% [markdown]
# <details>
#     <summary>▶<b>여기</b>를 눌러주세요</summary>
# <div markdown="1">
#
# ```python
# # is , not is -> 참조, 객체(same object, 오브젝트)비교
# # == , != -> 값 비교
# # 값, 참조가 같은 비교는 is 사용(중요)
#
# ```
# </div>
# </details>

# %% [markdown]
# ***
