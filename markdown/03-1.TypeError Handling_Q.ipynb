# %% [markdown]
# ---
# # 파이썬 입문 : 도전! 45가지 기초 문법 실습하기 🙋🏻‍♂️
# ---

# %% [markdown]
# ### 꼭 기억하세요 😊
# + **시간이 다소 소요되더라도** 스스로 생각해서 프로그래밍을 해야**`실력이 향상 됩니다.`**
# + 다양한 문제를 통해서 **`문제 해결`**능력을 향상 시켜봐요.
# + 여러 방식으로 **`같은 결과 값`**이 나오도록 프로그래밍 해보세요.
# + **문제 해결**에 너무 시간이 오래 걸리면 **`검색(구글링 등)`**을 통해서 해결해보세요.
# + **`온라인 Python IDE :`** https://www.programiz.com/python-programming/online-compiler/

# %% [markdown]
# ***
# ## 3. TypeError Handling💻
# ***
# #### **`연습예제1`** 💻

# %% [markdown]
# `아래 파이썬 코드가 왜` **`에러(예외)`**  `가 발생하는지 생각해보고` **`동작하도록 수정`** `후 코딩영역에 작성하세요.`
#
# ```python
# x = "Seoul"
# y = 25
# z = x + y
#
# print(f'x + y : {z}')
# ```

# %% [markdown]
# #### **`코딩영역1`**

# %%
# 코딩 영역
import this
# 파이썬은 다른 타입의 연산을 허가하지 않음 (toString() 으로 변경되어서 합해지지 않음) -> TypeError
x = "Seoul"
y = 25
# z = x + y
z = x + str(y)

print(f'x + y : {z}')

print('===숫자로 합해보기===')
print('각 문자를 아스키 번호로 바꾸고 모든 아스키 num 의 합')

x = "Seoul"
y = 25
# 내가 만든거
# z = sum(list(map(lambda ch: ord(ch), x))) + y

# 와... 씨 이건 뭐냐?
z = sum(map(ord, x))+y
print(f'x + y : {z}')

# 두개 완전히 같음 (문자열이 문자들의 배열 구조라고 까먹지 말아야할 듯)
# print(list(map(lambda ch: ord(ch), x)))
# print(list(map(ord, x)))

# print(f'x + y : {z}')
# Out:
# x + y : Seoul25
# ===숫자로 합해보기===
# 각 문자를 아스키 번호로 바꾸고 모든 아스키 num 의 합
# x + y : 545
# [83, 101, 111, 117, 108]
# [83, 101, 111, 117, 108]

# %%
# TypeError 에러 모음
# TypeError: 'str' object is not callable
# str = "hello world"
# print(str())

# TypeError: list indices must be integers or slices, not str
# arr = [1,2,3,4,5]
# print(arr['1:2'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 7
#       1 # TypeError 에러 모음
#       2 # TypeError: 'str' object is not callable
#       3 # str = "hello world"
#       4 # print(str())
#       6 arr = [1,2,3,4,5]
# ----> 7 print(arr['2'])
#
# TypeError: list indices must be integers or slices, not str

# %% [markdown]
# print(list(map(ord, x)))
# #### **`Hint`**

# %% [markdown]
# <details>
#     <summary>▶<b>여기</b>를 눌러주세요</summary>
# <div markdown="1">
#
# ```python
# # 문자열 <-> 정수 연산은 형변환(Type Casting)이 필요
# # Calling a non-callable 인 경우
# # 리스트 인덱스 타입 에러인 경우
# # 기타 타입 에러
#
# ```
# </div>
# </details>

# %% [markdown]
# ***
