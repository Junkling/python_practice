# %% [markdown]
# ---
# # 파이썬 입문 : 도전! 45가지 기초 문법 실습하기 🙋🏻‍♂️
# ---

# %% [markdown]
# ### 꼭 기억하세요 😊
# + **시간이 다소 소요되더라도** 스스로 생각해서 프로그래밍을 해야**`실력이 향상 됩니다.`**
# + 다양한 문제를 통해서 **`문제 해결`**능력을 향상 시켜봐요.
# + 여러 방식으로 **`같은 결과 값`**이 나오도록 프로그래밍 해보세요.
# + **문제 해결**에 너무 시간이 오래 걸리면 **`검색(구글링 등)`**을 통해서 해결해보세요.
# + **`온라인 Python IDE :`** https://www.programiz.com/python-programming/online-compiler/

# %% [markdown]
# ***
# ## 21. String Split By Delimiter💻
# ***
# #### **`연습예제`** 💻

# %% [markdown]
# `아래와 같은` **`문장을 공백`** `으로` **`구분 후`** `단어 개수를 출력하는` **`함수`** `를 작성 후 실행하세요.` **`input 함수 가능`**
#
#
# ```python
# in_str = "Suppose we have few words that are separated by spaces."
#
# 출력 결과 : 10
# ```

# %% [markdown]
# #### **`코딩영역`**

# %%
# 코딩 영역
in_str = "Suppose we have few words that are separated by spaces."

count = 0
for s in in_str:
    if s == ' ': count += 1
else:
    if in_str :
        count +=1

print('answer1 = ',count)
print('answer2 = ',len(list(in_str.split(' '))))
sum_1 = sum(map(lambda x: x == ' ', list(in_str)))
if in_str :
    sum_1 +=1
print('answer3 = ',sum_1)

in_str2 = input('문자를 입력하세요')
splitCha = input('구분좌를 입력하세요')

count = 0
for s in in_str2:
    if s == splitCha: count += 1
else:
    if in_str2 :
        count +=1

print('answer4 = ',count)

print('answer5 = ',len(list(in_str2.split(splitCha))))
sum_2 = sum(map(lambda x: x == splitCha, list(in_str2)))
if in_str2 :
    sum_2 +=1
print('answer6 = ',sum_2)
# Out:
# answer1 =  10
# answer2 =  10
# answer3 =  10
# answer4 =  4
# answer5 =  4
# answer6 =  4

# %% [markdown]
# #### **`Hint`**

# %% [markdown]
# <details>
#     <summary>▶<b>여기</b>를 눌러주세요</summary>
# <div markdown="1">
#
# ```python
# # Python split() 함수는 자주사용해요.
# # string.split(separator, maxsplit) : 구분자, 분할 수
# # 기본 분리 지정자는 공백
# # 문자열을 구분 후 리스트로 변환
# ```
# </div>
# </details>

# %% [markdown]
# ***
